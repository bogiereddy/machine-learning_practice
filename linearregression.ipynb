# %% [markdown]
# <a href="https://colab.research.google.com/github/bogiereddy/machine-learning_practice/blob/main/linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data ={'hours':[1,2,3,4],
        'marks':[20,40,50,60]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    hours  marks
# 0      1     20
# 1      2     40
# 2      3     50
# 3      4     60

# %%
X=df['hours'].values
y=df['marks'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
slope =model.coef_[0]

# %%
intercept = model.intercept_

# %%
print(f"slope(m):{slope}")
print(f"intercept(b):{intercept}")
print(f"equation of the regression line: y ={slope:.2f}x +{intercept:.2f}")
# Out:
# slope(m):13.000000000000002
# intercept(b):9.999999999999993
# equation of the regression line: y =13.00x +10.00

# %%
df['predicted_marks']= model.predict(X.reshape(-1, 1))

# %%
df.head()
# Out:
#    hours  marks  predicted_marks
# 0      1     20             23.0
# 1      2     40             36.0
# 2      3     50             49.0
# 3      4     60             62.0

# %%
plt.scatter(df['hours'],df['marks'],color='blue',label='actual_marks')

# %%
plt.plot(df['hours'],df['predicted_marks'],color='red',label='Regression line')
plt.xlabel('Hours Studied')
plt.ylabel('marks')
plt.title('linear regression')
plt.legend()
plt.show()

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git add .

# %%
# !git commit -m "Initial commit of my resources"
# Out:
# [master (root-commit) a562721] Initial commit of my resources
#  21 files changed, 51059 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2026.05.12/13.28.53.384927.log
#  create mode 100644 .config/logs/2026.05.12/13.29.12.483949.log
#  create mode 100644 .config/logs/2026.05.12/13.29.25.418951.log
#  create mode 100644 .config/logs/2026.05.12/13.29.27.205677.log
#  create mode 100644 .config/logs/2026.05.12/13.29.39.608616.log
#  create mode 100644 .config/logs/2026.05.12/13.29.40.400999.log
# ...

# %%
# !git remote add origin <https://github.com/bogiereddy/machine-learning-_practice.git>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git remote add origin <https://github.com/bogiereddy/machine-learning-_practice.git>'

# %%
# !git remote add origin https://github.com/bogiereddy/machine-learning-_practice.git
