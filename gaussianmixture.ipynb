# %% [markdown]
# <a href="https://colab.research.google.com/github/bogiereddy/machine-learning_practice/blob/main/gaussianmixture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# is a probabilistic machine learning algorithm used primarily for clustering and density estimation.
#
# GMM uses the Expectation(updatevariables)-Maximization (update hypothesis) algorithm to iteratively find the best-fitting distributions.
#
# gaussian defined by three :
#
# mean
# covariances
# weight

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(
    n_samples = 100,
    centers = 3,
    random_state = 42,
    cluster_std = [1.0,1.5,0.8]
)

# %%
gmm = GaussianMixture(
    n_components=3,
    covariance_type='full',
    random_state=42
)
gmm.fit(X)
labels = gmm.predict(X)

# %%
plt.figure(figsize=(8, 6))

# scatter points colored by hard labels
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, edgecolor='k')

# plot Gaussian centers
plt.scatter(
    gmm.means_[:, 0],
    gmm.means_[:, 1],
    s=300,
    c='red',
    marker='X',
    label='Centers'
)

plt.title("Gaussian Mixture Model Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# A Dirichlet Process Mixture Model (DPMM) : is a powerful Bayesian nonparametric clustering method. Unlike traditional methods like K-means or finite Gaussian mixture models, DPMMs sidestep the need to specify the number of clusters in advance.
